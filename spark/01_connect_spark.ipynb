# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("Bronze Reader")
    .master("spark://spark-master:7077")
    .getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[2], line 5
#       1 spark = (
#       2     SparkSession.builder
#       3     .appName("Bronze Reader")
#       4     .master("spark://spark-master:7077")
# ----> 5     .getOrCreate()
#       6 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# ...

# %%
df = spark.read.csv(
    "s3a://bronze-layer/olist_orders_dataset.csv",
    header=True
)
